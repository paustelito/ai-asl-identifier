# %% [markdown]
# # AI ASL Identifier

# %% [markdown]
# ## Preprocesado de los datos

# %% [markdown]
# ### Split test-train

# %%
from pathlib import Path # para cargar imágenes en local

DATA_DIR = Path("images/")

# Obtener todas las imagenes para rehacer split
image_paths = list(DATA_DIR.glob("**/*.jpg"))
labels = [p.parent.name for p in image_paths]

print(f"Se encontraron {len(image_paths)} imágenes")
# Out:
# Se encontraron 165782 imágenes
